# %% [markdown]
# <a href="https://colab.research.google.com/github/TrongHvDev/AI/blob/main/Homework_week7/Social_Network_ads.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Social_Network_Ads.csv')
data.hist()
plt.show()

# %%
data.corr()
# Out:
#                   User ID       Age  EstimatedSalary  Purchased
# User ID          1.000000 -0.000721         0.071097   0.007120
# Age             -0.000721  1.000000         0.155238   0.622454
# EstimatedSalary  0.071097  0.155238         1.000000   0.362083
# Purchased        0.007120  0.622454         0.362083   1.000000

# %%
sas.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Ta thay purchased phu thuoc vao age

# %%
data.plot(kind = 'scatter', x = 'Age', y = 'Purchased', figsize = (9, 9), color = 'black')
# Out:
# <Axes: xlabel='Age', ylabel='Purchased'>

# %% [markdown]
# bac 1

# %%
model = linear_model.LinearRegression()
X = pd.DataFrame(data['Age'])
y = data['Purchased']    
model.fit(X, y)
print('Intercept của mô hình bậc 1: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 1: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))
data.plot(kind = 'scatter', x = 'Age', y = 'Purchased', figsize = (9, 9), color = 'black')
y_pred = model.predict(X)
plt.plot(data['Age'], y_pred, color = 'red')
# Out:
# Intercept của mô hình bậc 1:
# -0.7154209274697418
# Coeffient của mô hình bậc 1:
# [0.02849345]
# Độ chính xác của mô hình:
# 0.387449229708981
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# bac 2

# %%
model = linear_model.LinearRegression()
X_2 = pd.DataFrame([data['Age'], data['Age'] **2]).T    # a1x + a2x^2 + b, .T la nghich dao
model.fit(X_2, y = data['Purchased'])
print('Intercept của mô hình bậc 2: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 2: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X_2, y))
range = np.arange(10, 70, 1)
predictor = pd.DataFrame([range, range **2]).T
y_pred = model.predict(X = predictor)
data.plot(kind = 'scatter', x = 'Age', y = 'Purchased', figsize = (9, 9), color = 'black')
plt.plot(range, y_pred, color = 'red')
# Out:
# Intercept của mô hình bậc 2:
# -0.10601582739866239
# Coeffient của mô hình bậc 2:
# [-0.00535925  0.00043556]
# Độ chính xác của mô hình:
# 0.40052074482714484
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model = linear_model.LinearRegression()
X_10 = pd.DataFrame([data['Age'], data['Age'] **2, data['Age']**3, data['Age']**4, 
                    data['Age']**5, data['Age']**6, data['Age']**7,
                    data['Age']**8, data['Age']**9, data['Age']**10]).T    # a1x + a2x^2 + b, .T la nghich dao
model.fit(X_10, y = data['Purchased'])
print('Intercept của mô hình bậc 10: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 10: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X_10, y))
range = np.arange(10, 65, 0.1)
predictor = pd.DataFrame([range, range **2, range **3, range **4, range **5,
                          range **6, range **7, range **8, 
                          range **9, range **10]).T
y_pred = model.predict(X = predictor)
data.plot(kind = 'scatter', x = 'Age', y = 'Purchased', figsize = (9, 9), color = 'black')
plt.plot(range, y_pred, color = 'red')
# Out:
# Intercept của mô hình bậc 10:
# 1.9577088088011987
# Coeffient của mô hình bậc 10:
# [-1.33145348e-07 -2.25147952e-06 -4.08702853e-05 -2.80115564e-04
#   3.59282500e-05 -1.92491783e-06  5.49043984e-08 -8.75786859e-10
#   7.39131443e-12 -2.57611540e-14]
# Độ chính xác của mô hình:
# 0.4407628028693059
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
