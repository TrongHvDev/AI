# %% [markdown]
# <a href="https://colab.research.google.com/github/TrongHvDev/AI/blob/main/Week13/MFCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python_speech_features
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5886 sha256=b485a071918c5ac6482c9c801cb5344f7d654c157c55bd6360429fecb3304f8d
#   Stored in directory: /root/.cache/pip/wheels/09/a1/04/08e2688d2562d8f9ff89e77c6ddfbf7268e07dae1a6f22455e
# Successfully built python_speech_features
# ...

# %%
# MFCC
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc, logfbank
frequency_sample, audio_signal = wavfile.read('TiengChoSua.wav')
audio_signal = audio_signal[:1500]
feature_mfcc = mfcc(audio_signal, frequency_sample)
print('\nMFCC: \n Number of window = ', feature_mfcc.shape[0])
print('Length of each feature: ', feature_mfcc.shape[1])
feature_mfcc = feature_mfcc.T
plt.matshow(feature_mfcc)
plt.title('MFCC')
# Out:
# <ipython-input-3-ccd17a6bf52e>:6: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   frequency_sample, audio_signal = wavfile.read('TiengChoSua.wav')
# WARNING:root:frame length (1103) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# MFCC:
#  Number of window =  6
# Length of each feature:  13
# Text(0.5, 1.0, 'MFCC')

# %%
# filterback_feature = logfbank(audio_signal, frequency_sample)
# print('\nFilter bank: \n Number of window = ', filterback_feature.shape[0])
# print('Length of each feature: ', filterback_feature.shape[1])
# filterback_feature = filterback_feature.T
# plt.matshow(filterback_feature)
# plt.title('filter bank')
# plt.show()
# Out:
# WARNING:root:frame length (1103) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# Filter bank:
#  Number of window =  6
# Length of each feature:  26
