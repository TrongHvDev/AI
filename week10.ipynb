# %% [markdown]
# <a href="https://colab.research.google.com/github/TrongHvDev/AI/blob/main/week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/AI/Backup_AI/cifar100.h5')

# %%
from keras.utils import load_img
from matplotlib import pyplot as plt

# %%
from keras.utils.image_utils import img_to_array
import numpy as np

img = load_img('/content/drive/MyDrive/AI/Anh_test/mec_car.jpg', target_size = (32,32))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32') /255
np.argmax(model.predict(img), axis = -1)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([85])

# %%
img1 = load_img('/content/drive/MyDrive/AI/Anh_test/meo1.jpg', target_size = (32,32))
plt.imshow(img1)
img1 = img_to_array(img)
img1 = img.reshape(1,32*32*3)
img1 = img.astype('float32') /255
np.argmax(model.predict(img1), axis = -1)
# Out:
# 1/1 [==============================] - 0s 126ms/step
# array([74])

# %%
from matplotlib.image import imread
from matplotlib import pyplot as plt
folder = '/content/drive/MyDrive/AI/Anh_test'
for i in range(30):
  plt.subplot(5, 6, i + 1)
  filename = folder + '/'+  'A' + str(i) + '.jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show()
