# %% [markdown]
# <a href="https://colab.research.google.com/github/TrongHvDev/AI/blob/main/week12_preTrained/pre_trainedmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.7 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '341022344_625329628977637_8276782054775520236_n.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
i = 0
for face in faces:
  print(face)
  i = i +1 
  print(i)
# Out:
# ...
# 4/4 [==============================] - 0s 4ms/step
# {'box': [1054, 590, 42, 51], 'confidence': 0.9999972581863403, 'keypoints': {'left_eye': (1066, 607), 'right_eye': (1085, 607), 'nose': (1076, 618), 'mouth_left': (1067, 628), 'mouth_right': (1083, 629)}}
# 1
# {'box': [247, 735, 55, 65], 'confidence': 0.9999885559082031, 'keypoints': {'left_eye': (259, 759), 'right_eye': (283, 754), 'nose': (273, 768), 'mouth_left': (264, 782), 'mouth_right': (290, 776)}}
# 2
# {'box': [1263, 589, 41, 53], 'confidence': 0.9999829530715942, 'keypoints': {'left_eye': (1274, 607), 'right_eye': (1293, 607), 'nose': (1284, 618), 'mouth_left': (1275, 628), 'mouth_right': (1293, 627)}}
# 3
# {'box': [839, 610, 42, 48], 'confidence': 0.9999793767929077, 'keypoints': {'left_eye': (852, 630), 'right_eye': (872, 628), 'nose': (864, 641), 'mouth_left': (855, 649), 'mouth_right': (870, 647)}}
# 4
# ...

# %%
filename = '2.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x, y), width, height,
                       fill = False, color = 'red')
  ax.add_patch(rect)  # chồng ảnh lên ảnh khác
  for key, value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'green')
    ax.add_patch(dot)
    plt.savefig('3.jpg')

plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 3ms/step

# %%
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1, y1, width, height = result_list[i]['box']
    x2, y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i + 1)
    plt.axis('off')
    face_img = data[y1: y2, x1: x2]
    plt.imshow(face_img)
    plt.imsave(f'face_{i+1}.jpg', face_img)
  plt.show()

# %%
filename = 'Anh.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 4/4 [==============================] - 0s 3ms/step
